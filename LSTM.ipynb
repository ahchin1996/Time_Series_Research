# %%
from math import sqrt
from numpy import concatenate
from matplotlib import pyplot
from pandas import read_csv
from pandas import DataFrame
from pandas import concat
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from sklearn.model_selection import train_test_split
import numpy as np
# Out:
# Using TensorFlow backend.
# C:\Users\cooke\.conda\envs\tf\lib\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\cooke\.conda\envs\tf\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\cooke\.conda\envs\tf\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\cooke\.conda\envs\tf\lib\site-packages\tensorflow\python\framework\dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\cooke\.conda\envs\tf\lib\site-packages\tensorflow\python\framework\dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\cooke\.conda\envs\tf\lib\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# C:\Users\cooke\.conda\envs\tf\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\cooke\.conda\envs\tf\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\cooke\.conda\envs\tf\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\cooke\.conda\envs\tf\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\cooke\.conda\envs\tf\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\cooke\.conda\envs\tf\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
# convert series to supervised learning
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
    n_vars = 1 if type(data) is list else data.shape[1]
    df = DataFrame(data)
    cols, names = list(), list()
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
    # put it all together
    agg = concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg

# %%
# load dataset
dataset = read_csv('D:/Data/stock/denque1.csv', header=0, index_col=0)
values = dataset.values
dataset.info()
print(dataset.isnull().sum())
# integer encode direction
encoder = LabelEncoder()
values[:,4] = encoder.fit_transform(values[:,4])
# ensure all data is float
values = values.astype('float32')
# normalize features
scaler = MinMaxScaler(feature_range=(0, 1))
scaled = scaler.fit_transform(values)
# specify the number of lag hours
n_hours = 1
n_features = 9
# frame as supervised learning
reframed = series_to_supervised(scaled, n_hours, 1)
print(reframed.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 261 entries, 2010/1/2 00:00 to 2010/1/12 20:00
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   denque              261 non-null    int64
#  1   MeanHumidity        261 non-null    float64
#  2   Precipitations      261 non-null    int64
#  3   MeanPrecipitations  261 non-null    float64
#  4   MeanSunshine        261 non-null    float64
#  5   HighestTemperature  261 non-null    float64
#  6   LowestTemperature   261 non-null    float64
#  7   MeanTemperature     261 non-null    float64
#  8   NumberOfSearches    261 non-null    int64
# dtypes: float64(6), int64(3)
# memory usage: 20.4+ KB
# denque                0
# MeanHumidity          0
# Precipitations        0
# MeanPrecipitations    0
# MeanSunshine          0
# HighestTemperature    0
# LowestTemperature     0
# MeanTemperature       0
# NumberOfSearches      0
# dtype: int64
# (260, 18)

# %%
# split into train and test sets
values = reframed.values
rumtime=10
score=[[0]*4 for i in range(rumtime)]

# %%
for i in range(rumtime): 
    train, test = train_test_split(values, random_state=0, train_size=0.985)
    print(train)
    print(test)
    # split into input and outputs
    n_obs = n_hours * n_features
    train_X, train_y = train[:, :n_obs], train[:, -n_features]
    test_X, test_y = test[:, :n_obs], test[:, -n_features]
    print(train_X.shape, len(train_X), train_y.shape)
    # reshape input to be 3D [samples, timesteps, features]
    train_X = train_X.reshape((train_X.shape[0], n_hours, n_features))
    test_X = test_X.reshape((test_X.shape[0], n_hours, n_features))
    print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)

    # design network
    model = Sequential()
    model.add(LSTM(50, input_shape=(train_X.shape[1], train_X.shape[2])))
    model.add(Dense(1))
    model.compile(loss='mae', optimizer='adam')
    # fit network
    history = model.fit(train_X, train_y, epochs=50, batch_size=72, validation_data=(test_X, test_y), verbose=2, shuffle=False)
    # plot history
    # 回復Training資料值為原始數據的規模
    trainPredict = model.predict(train_X)
    train_X = train_X.reshape((train_X.shape[0], n_hours*n_features))
    # invert scaling for forecast
    trainPredict = concatenate((trainPredict, train_X[:,  -(n_features-1):]), axis=1)
    trainPredict = scaler.inverse_transform(trainPredict)
    trainPredict = trainPredict[:,0]
    # invert scaling for actual
    train_y = train_y.reshape((len(train_y), 1))
    train_y = concatenate((train_y, train_X[:,  -(n_features-1):]), axis=1)
    train_y = scaler.inverse_transform(train_y)
    train_y = train_y[:,0]
    
    # 回復Testing資料值為原始數據的規模
    testPredict = model.predict(test_X)
    test_X = test_X.reshape((test_X.shape[0], n_hours*n_features))
    # invert scaling for forecast
    testPredict = concatenate((testPredict, test_X[:, -(n_features-1):]), axis=1)
    testPredict = scaler.inverse_transform(testPredict)
    testPredict = testPredict[:,0]
    # invert scaling for actual
    test_y = test_y.reshape((len(test_y), 1))
    test_y = concatenate((test_y, test_X[:,  -(n_features-1):]), axis=1)
    test_y = scaler.inverse_transform(test_y)
    test_y = test_y[:,0]

    # calculate RMSE
    
    #calculate 均方根誤差(root mean squared error)
    trainScore = sqrt(mean_squared_error(train_y, trainPredict))
    print('Train RMSE: %.4f' % (trainScore))
    
    testScore = sqrt(mean_squared_error(test_y, testPredict))
    print('Test RMSE: %.4f' % (testScore))
    n = len(test_y)
    mape = sum(np.abs((test_y - testPredict)/test_y))/n*100
    print('Test MAPE: %.4f' % (mape))
    pyplot.plot(test_y, color =  'red', label = 'Real Denque Case')  # 紅線表示真實登革熱數
    pyplot.plot(testPredict, color = 'blue', label = 'Predicted Denque Case')  # 藍線表示預測登革熱數
    pyplot.xlabel('Time')
    pyplot.ylabel('dengue case')
    pyplot.legend()
    pyplot.show()
    
    score[i][0]=trainScore
    score[i][1]=testScore
    score[i][2]=trainPredict.tolist()
    score[i][3]=testPredict.tolist()
# Out:
# [[3.8925651e-04 5.3103614e-01 5.2287583e-03 ... 6.8202770e-01
#   7.8022289e-01 2.6999998e-01]
#  [0.0000000e+00 1.8172097e-01 0.0000000e+00 ... 6.1751151e-01
#   6.6476560e-01 1.7999999e-01]
#  [0.0000000e+00 4.2572784e-01 0.0000000e+00 ... 4.7004607e-01
#   3.3966637e-01 0.0000000e+00]
#  ...
#  [3.8925651e-04 7.8467488e-01 9.2810459e-02 ... 3.8709679e-01
#   4.3990147e-01 0.0000000e+00]
#  [3.2347217e-01 6.0338187e-01 0.0000000e+00 ... 3.6866364e-01
#   4.0814674e-01 0.0000000e+00]
#  [0.0000000e+00 6.6759419e-01 6.0130719e-02 ... 5.8986175e-01
#   5.9728706e-01 2.6999998e-01]]
# [[3.89256515e-04 9.27654266e-01 7.33333349e-01 7.33333409e-01
#   4.62962966e-03 6.18055463e-01 8.01843286e-01 7.45809197e-01
#   9.99999940e-02 3.89256515e-04 6.53681517e-01 1.17647061e-02
#   1.17647061e-02 8.61111104e-01 7.36111045e-01 8.94009233e-01
#   8.85197997e-01 2.89999992e-01]
#  [3.69793698e-02 8.00299883e-01 5.75163402e-02 5.75163402e-02
#   2.31481478e-01 3.33333254e-01 4.42396373e-01 3.81594777e-01
#   0.00000000e+00 1.24562085e-02 7.08690166e-01 3.66013087e-02
#   3.66013087e-02 9.72222239e-02 3.12500000e-01 3.68663639e-01
#   2.32841492e-01 0.00000000e+00]
#  [0.00000000e+00 6.41695261e-01 9.28104594e-02 9.28104669e-02
#   7.91666687e-01 7.56944537e-01 8.43317986e-01 8.97876620e-01
#   2.19999999e-01 7.78513029e-04 6.79580450e-01 6.66666701e-02
#   6.66666701e-02 4.44444448e-01 7.29166627e-01 8.94009233e-01
#   8.65466952e-01 1.89999998e-01]
#  [2.72479560e-03 6.50256872e-01 0.00000000e+00 0.00000000e+00
#   1.00000000e+00 7.22222209e-01 9.35483932e-01 9.39882278e-01
#   0.00000000e+00 1.94628257e-03 5.77054977e-01 0.00000000e+00
#   0.00000000e+00 9.95370388e-01 7.70833135e-01 9.81566787e-01
#   9.77802634e-01 0.00000000e+00]]
# (256, 9) 256 (256,)
# (256, 1, 9) (256,) (4, 1, 9) (4,)
# WARNING:tensorflow:From C:\Users\cooke\.conda\envs\tf\lib\site-packages\keras\backend\tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\cooke\.conda\envs\tf\lib\site-packages\keras\backend\tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From C:\Users\cooke\.conda\envs\tf\lib\site-packages\keras\backend\tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From C:\Users\cooke\.conda\envs\tf\lib\site-packages\keras\optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From C:\Users\cooke\.conda\envs\tf\lib\site-packages\tensorflow\python\ops\math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From C:\Users\cooke\.conda\envs\tf\lib\site-packages\keras\backend\tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From C:\Users\cooke\.conda\envs\tf\lib\site-packages\keras\backend\tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# Train on 256 samples, validate on 4 samples
# Epoch 1/50
#  - 6s - loss: 0.0655 - val_loss: 0.0216
# Epoch 2/50
#  - 0s - loss: 0.0614 - val_loss: 0.0125
# Epoch 3/50
#  - 0s - loss: 0.0578 - val_loss: 0.0107
# Epoch 4/50
#  - 0s - loss: 0.0558 - val_loss: 0.0118
# Epoch 5/50
#  - 0s - loss: 0.0551 - val_loss: 0.0111
# Epoch 6/50
#  - 0s - loss: 0.0549 - val_loss: 0.0119
# Epoch 7/50
#  - 0s - loss: 0.0542 - val_loss: 0.0090
# Epoch 8/50
#  - 0s - loss: 0.0530 - val_loss: 0.0075
# Epoch 9/50
#  - 0s - loss: 0.0522 - val_loss: 0.0068
# Epoch 10/50
#  - 0s - loss: 0.0517 - val_loss: 0.0047
# Epoch 11/50
#  - 0s - loss: 0.0508 - val_loss: 0.0048
# Epoch 12/50
#  - 0s - loss: 0.0499 - val_loss: 0.0051
# Epoch 13/50
#  - 0s - loss: 0.0492 - val_loss: 0.0048
# Epoch 14/50
#  - 0s - loss: 0.0486 - val_loss: 0.0046
# Epoch 15/50
#  - 0s - loss: 0.0480 - val_loss: 0.0050
# Epoch 16/50
#  - 0s - loss: 0.0476 - val_loss: 0.0043
# Epoch 17/50
#  - 0s - loss: 0.0467 - val_loss: 0.0041
# Epoch 18/50
#  - 0s - loss: 0.0459 - val_loss: 0.0036
# Epoch 19/50
#  - 0s - loss: 0.0454 - val_loss: 0.0041
# Epoch 20/50
#  - 0s - loss: 0.0450 - val_loss: 0.0041
# Epoch 21/50
#  - 0s - loss: 0.0446 - val_loss: 0.0029
# Epoch 22/50
#  - 0s - loss: 0.0431 - val_loss: 0.0031
# Epoch 23/50
#  - 0s - loss: 0.0425 - val_loss: 0.0030
# Epoch 24/50
#  - 0s - loss: 0.0420 - val_loss: 0.0029
# Epoch 25/50
#  - 0s - loss: 0.0415 - val_loss: 0.0034
# Epoch 26/50
#  - 0s - loss: 0.0410 - val_loss: 0.0030
# Epoch 27/50
#  - 0s - loss: 0.0397 - val_loss: 0.0031
# Epoch 28/50
#  - 0s - loss: 0.0390 - val_loss: 0.0033
# Epoch 29/50
#  - 0s - loss: 0.0383 - val_loss: 0.0040
# Epoch 30/50
#  - 0s - loss: 0.0378 - val_loss: 0.0031
# Epoch 31/50
#  - 0s - loss: 0.0369 - val_loss: 0.0026
# Epoch 32/50
#  - 0s - loss: 0.0358 - val_loss: 0.0028
# Epoch 33/50
#  - 0s - loss: 0.0348 - val_loss: 0.0032
# Epoch 34/50
#  - 0s - loss: 0.0340 - val_loss: 0.0040
# Epoch 35/50
#  - 0s - loss: 0.0333 - val_loss: 0.0041
# Epoch 36/50
#  - 0s - loss: 0.0323 - val_loss: 0.0046
# Epoch 37/50
#  - 0s - loss: 0.0316 - val_loss: 0.0036
# Epoch 38/50
#  - 0s - loss: 0.0303 - val_loss: 0.0037
# Epoch 39/50
#  - 0s - loss: 0.0292 - val_loss: 0.0049
# Epoch 40/50
#  - 0s - loss: 0.0283 - val_loss: 0.0059
# Epoch 41/50
#  - 0s - loss: 0.0276 - val_loss: 0.0055
# Epoch 42/50
#  - 0s - loss: 0.0265 - val_loss: 0.0041
# Epoch 43/50
#  - 0s - loss: 0.0251 - val_loss: 0.0043
# Epoch 44/50
#  - 0s - loss: 0.0239 - val_loss: 0.0049
# Epoch 45/50
#  - 0s - loss: 0.0228 - val_loss: 0.0058
# Epoch 46/50
#  - 0s - loss: 0.0218 - val_loss: 0.0073
# Epoch 47/50
#  - 0s - loss: 0.0212 - val_loss: 0.0065
# Epoch 48/50
#  - 0s - loss: 0.0198 - val_loss: 0.0057
# Epoch 49/50
#  - 0s - loss: 0.0185 - val_loss: 0.0054
# Epoch 50/50
#  - 0s - loss: 0.0175 - val_loss: 0.0062
# Train RMSE: 135.9375
# Test RMSE: 20.3060
# Test MAPE: 724.6613
# [[3.8925651e-04 5.3103614e-01 5.2287583e-03 ... 6.8202770e-01
#   7.8022289e-01 2.6999998e-01]
#  [0.0000000e+00 1.8172097e-01 0.0000000e+00 ... 6.1751151e-01
#   6.6476560e-01 1.7999999e-01]
#  [0.0000000e+00 4.2572784e-01 0.0000000e+00 ... 4.7004607e-01
#   3.3966637e-01 0.0000000e+00]
#  ...
#  [3.8925651e-04 7.8467488e-01 9.2810459e-02 ... 3.8709679e-01
#   4.3990147e-01 0.0000000e+00]
#  [3.2347217e-01 6.0338187e-01 0.0000000e+00 ... 3.6866364e-01
#   4.0814674e-01 0.0000000e+00]
#  [0.0000000e+00 6.6759419e-01 6.0130719e-02 ... 5.8986175e-01
#   5.9728706e-01 2.6999998e-01]]
# [[3.89256515e-04 9.27654266e-01 7.33333349e-01 7.33333409e-01
#   4.62962966e-03 6.18055463e-01 8.01843286e-01 7.45809197e-01
#   9.99999940e-02 3.89256515e-04 6.53681517e-01 1.17647061e-02
#   1.17647061e-02 8.61111104e-01 7.36111045e-01 8.94009233e-01
#   8.85197997e-01 2.89999992e-01]
#  [3.69793698e-02 8.00299883e-01 5.75163402e-02 5.75163402e-02
#   2.31481478e-01 3.33333254e-01 4.42396373e-01 3.81594777e-01
#   0.00000000e+00 1.24562085e-02 7.08690166e-01 3.66013087e-02
#   3.66013087e-02 9.72222239e-02 3.12500000e-01 3.68663639e-01
#   2.32841492e-01 0.00000000e+00]
#  [0.00000000e+00 6.41695261e-01 9.28104594e-02 9.28104669e-02
#   7.91666687e-01 7.56944537e-01 8.43317986e-01 8.97876620e-01
#   2.19999999e-01 7.78513029e-04 6.79580450e-01 6.66666701e-02
#   6.66666701e-02 4.44444448e-01 7.29166627e-01 8.94009233e-01
#   8.65466952e-01 1.89999998e-01]
#  [2.72479560e-03 6.50256872e-01 0.00000000e+00 0.00000000e+00
#   1.00000000e+00 7.22222209e-01 9.35483932e-01 9.39882278e-01
#   0.00000000e+00 1.94628257e-03 5.77054977e-01 0.00000000e+00
#   0.00000000e+00 9.95370388e-01 7.70833135e-01 9.81566787e-01
#   9.77802634e-01 0.00000000e+00]]
# (256, 9) 256 (256,)
# (256, 1, 9) (256,) (4, 1, 9) (4,)
# Train on 256 samples, validate on 4 samples
# Epoch 1/50
#  - 1s - loss: 0.1127 - val_loss: 0.0780
# Epoch 2/50
#  - 0s - loss: 0.0785 - val_loss: 0.0256
# Epoch 3/50
#  - 0s - loss: 0.0575 - val_loss: 0.0133
# Epoch 4/50
#  - 0s - loss: 0.0653 - val_loss: 0.0075
# Epoch 5/50
#  - 0s - loss: 0.0560 - val_loss: 0.0161
# Epoch 6/50
#  - 0s - loss: 0.0549 - val_loss: 0.0254
# Epoch 7/50
#  - 0s - loss: 0.0559 - val_loss: 0.0186
# Epoch 8/50
#  - 0s - loss: 0.0523 - val_loss: 0.0080
# Epoch 9/50
#  - 0s - loss: 0.0517 - val_loss: 0.0065
# Epoch 10/50
#  - 0s - loss: 0.0504 - val_loss: 0.0104
# Epoch 11/50
#  - 0s - loss: 0.0494 - val_loss: 0.0136
# Epoch 12/50
#  - 0s - loss: 0.0488 - val_loss: 0.0082
# Epoch 13/50
#  - 0s - loss: 0.0477 - val_loss: 0.0059
# Epoch 14/50
#  - 0s - loss: 0.0467 - val_loss: 0.0087
# Epoch 15/50
#  - 0s - loss: 0.0459 - val_loss: 0.0071
# Epoch 16/50
#  - 0s - loss: 0.0451 - val_loss: 0.0050
# Epoch 17/50
#  - 0s - loss: 0.0442 - val_loss: 0.0060
# Epoch 18/50
#  - 0s - loss: 0.0435 - val_loss: 0.0042
# Epoch 19/50
#  - 0s - loss: 0.0427 - val_loss: 0.0036
# Epoch 20/50
#  - 0s - loss: 0.0419 - val_loss: 0.0031
# Epoch 21/50
#  - 0s - loss: 0.0412 - val_loss: 0.0029
# Epoch 22/50
#  - 0s - loss: 0.0405 - val_loss: 0.0022
# Epoch 23/50
#  - 0s - loss: 0.0397 - val_loss: 0.0017
# Epoch 24/50
#  - 0s - loss: 0.0390 - val_loss: 0.0012
# Epoch 25/50
#  - 0s - loss: 0.0382 - val_loss: 0.0013
# Epoch 26/50
#  - 0s - loss: 0.0375 - val_loss: 0.0017
# Epoch 27/50
#  - 0s - loss: 0.0367 - val_loss: 0.0019
# Epoch 28/50
#  - 0s - loss: 0.0358 - val_loss: 0.0021
# Epoch 29/50
#  - 0s - loss: 0.0349 - val_loss: 0.0026
# Epoch 30/50
#  - 0s - loss: 0.0341 - val_loss: 0.0024
# Epoch 31/50
#  - 0s - loss: 0.0332 - val_loss: 0.0025
# Epoch 32/50
#  - 0s - loss: 0.0322 - val_loss: 0.0027
# Epoch 33/50
#  - 0s - loss: 0.0312 - val_loss: 0.0028
# Epoch 34/50
#  - 0s - loss: 0.0302 - val_loss: 0.0030
# Epoch 35/50
#  - 0s - loss: 0.0292 - val_loss: 0.0030
# Epoch 36/50
#  - 0s - loss: 0.0281 - val_loss: 0.0037
# Epoch 37/50
#  - 0s - loss: 0.0270 - val_loss: 0.0042
# Epoch 38/50
#  - 0s - loss: 0.0259 - val_loss: 0.0041
# Epoch 39/50
#  - 0s - loss: 0.0248 - val_loss: 0.0039
# Epoch 40/50
#  - 0s - loss: 0.0235 - val_loss: 0.0046
# Epoch 41/50
#  - 0s - loss: 0.0221 - val_loss: 0.0057
# Epoch 42/50
#  - 0s - loss: 0.0210 - val_loss: 0.0047
# Epoch 43/50
#  - 0s - loss: 0.0198 - val_loss: 0.0047
# Epoch 44/50
#  - 0s - loss: 0.0185 - val_loss: 0.0056
# Epoch 45/50
#  - 0s - loss: 0.0175 - val_loss: 0.0071
# Epoch 46/50
#  - 0s - loss: 0.0170 - val_loss: 0.0073
# Epoch 47/50
#  - 0s - loss: 0.0167 - val_loss: 0.0055
# Epoch 48/50
#  - 0s - loss: 0.0162 - val_loss: 0.0046
# Epoch 49/50
#  - 0s - loss: 0.0156 - val_loss: 0.0053
# Epoch 50/50
#  - 0s - loss: 0.0150 - val_loss: 0.0064
# Train RMSE: 108.8206
# Test RMSE: 22.8078
# Test MAPE: 548.3023
# [[3.8925651e-04 5.3103614e-01 5.2287583e-03 ... 6.8202770e-01
#   7.8022289e-01 2.6999998e-01]
#  [0.0000000e+00 1.8172097e-01 0.0000000e+00 ... 6.1751151e-01
#   6.6476560e-01 1.7999999e-01]
#  [0.0000000e+00 4.2572784e-01 0.0000000e+00 ... 4.7004607e-01
#   3.3966637e-01 0.0000000e+00]
#  ...
#  [3.8925651e-04 7.8467488e-01 9.2810459e-02 ... 3.8709679e-01
#   4.3990147e-01 0.0000000e+00]
#  [3.2347217e-01 6.0338187e-01 0.0000000e+00 ... 3.6866364e-01
#   4.0814674e-01 0.0000000e+00]
#  [0.0000000e+00 6.6759419e-01 6.0130719e-02 ... 5.8986175e-01
#   5.9728706e-01 2.6999998e-01]]
# [[3.89256515e-04 9.27654266e-01 7.33333349e-01 7.33333409e-01
#   4.62962966e-03 6.18055463e-01 8.01843286e-01 7.45809197e-01
#   9.99999940e-02 3.89256515e-04 6.53681517e-01 1.17647061e-02
#   1.17647061e-02 8.61111104e-01 7.36111045e-01 8.94009233e-01
#   8.85197997e-01 2.89999992e-01]
#  [3.69793698e-02 8.00299883e-01 5.75163402e-02 5.75163402e-02
#   2.31481478e-01 3.33333254e-01 4.42396373e-01 3.81594777e-01
#   0.00000000e+00 1.24562085e-02 7.08690166e-01 3.66013087e-02
#   3.66013087e-02 9.72222239e-02 3.12500000e-01 3.68663639e-01
#   2.32841492e-01 0.00000000e+00]
#  [0.00000000e+00 6.41695261e-01 9.28104594e-02 9.28104669e-02
#   7.91666687e-01 7.56944537e-01 8.43317986e-01 8.97876620e-01
#   2.19999999e-01 7.78513029e-04 6.79580450e-01 6.66666701e-02
#   6.66666701e-02 4.44444448e-01 7.29166627e-01 8.94009233e-01
#   8.65466952e-01 1.89999998e-01]
#  [2.72479560e-03 6.50256872e-01 0.00000000e+00 0.00000000e+00
#   1.00000000e+00 7.22222209e-01 9.35483932e-01 9.39882278e-01
#   0.00000000e+00 1.94628257e-03 5.77054977e-01 0.00000000e+00
#   0.00000000e+00 9.95370388e-01 7.70833135e-01 9.81566787e-01
#   9.77802634e-01 0.00000000e+00]]
# (256, 9) 256 (256,)
# (256, 1, 9) (256,) (4, 1, 9) (4,)
# Train on 256 samples, validate on 4 samples
# Epoch 1/50
#  - 1s - loss: 0.1025 - val_loss: 0.0310
# Epoch 2/50
#  - 0s - loss: 0.0637 - val_loss: 0.0120
# Epoch 3/50
#  - 0s - loss: 0.0662 - val_loss: 0.0222
# Epoch 4/50
#  - 0s - loss: 0.0668 - val_loss: 0.0115
# Epoch 5/50
#  - 0s - loss: 0.0588 - val_loss: 0.0076
# Epoch 6/50
#  - 0s - loss: 0.0570 - val_loss: 0.0092
# Epoch 7/50
#  - 0s - loss: 0.0544 - val_loss: 0.0031
# Epoch 8/50
#  - 0s - loss: 0.0543 - val_loss: 0.0032
# Epoch 9/50
#  - 0s - loss: 0.0527 - val_loss: 0.0045
# Epoch 10/50
#  - 0s - loss: 0.0517 - val_loss: 0.0042
# Epoch 11/50
#  - 0s - loss: 0.0515 - val_loss: 0.0042
# Epoch 12/50
#  - 0s - loss: 0.0504 - val_loss: 0.0035
# Epoch 13/50
#  - 0s - loss: 0.0495 - val_loss: 0.0053
# Epoch 14/50
#  - 0s - loss: 0.0491 - val_loss: 0.0038
# Epoch 15/50
#  - 0s - loss: 0.0485 - val_loss: 0.0045
# Epoch 16/50
#  - 0s - loss: 0.0479 - val_loss: 0.0043
# Epoch 17/50
#  - 0s - loss: 0.0474 - val_loss: 0.0039
# Epoch 18/50
#  - 0s - loss: 0.0468 - val_loss: 0.0042
# Epoch 19/50
#  - 0s - loss: 0.0462 - val_loss: 0.0039
# Epoch 20/50
#  - 0s - loss: 0.0456 - val_loss: 0.0037
# Epoch 21/50
#  - 0s - loss: 0.0451 - val_loss: 0.0038
# Epoch 22/50
#  - 0s - loss: 0.0445 - val_loss: 0.0029
# Epoch 23/50
#  - 0s - loss: 0.0440 - val_loss: 0.0041
# Epoch 24/50
#  - 0s - loss: 0.0433 - val_loss: 0.0027
# Epoch 25/50
#  - 0s - loss: 0.0425 - val_loss: 0.0031
# Epoch 26/50
#  - 0s - loss: 0.0419 - val_loss: 0.0031
# Epoch 27/50
#  - 0s - loss: 0.0413 - val_loss: 0.0021
# Epoch 28/50
#  - 0s - loss: 0.0405 - val_loss: 0.0021
# Epoch 29/50
#  - 0s - loss: 0.0398 - val_loss: 0.0021
# Epoch 30/50
#  - 0s - loss: 0.0391 - val_loss: 0.0025
# Epoch 31/50
#  - 0s - loss: 0.0384 - val_loss: 0.0027
# Epoch 32/50
#  - 0s - loss: 0.0376 - val_loss: 0.0024
# Epoch 33/50
#  - 0s - loss: 0.0367 - val_loss: 0.0018
# Epoch 34/50
#  - 0s - loss: 0.0358 - val_loss: 0.0014
# Epoch 35/50
#  - 0s - loss: 0.0350 - val_loss: 0.0019
# Epoch 36/50
#  - 0s - loss: 0.0341 - val_loss: 0.0023
# Epoch 37/50
#  - 0s - loss: 0.0332 - val_loss: 0.0023
# Epoch 38/50
#  - 0s - loss: 0.0322 - val_loss: 0.0031
# Epoch 39/50
#  - 0s - loss: 0.0312 - val_loss: 0.0032
# Epoch 40/50
#  - 0s - loss: 0.0301 - val_loss: 0.0025
# Epoch 41/50
#  - 0s - loss: 0.0289 - val_loss: 0.0022
# Epoch 42/50
#  - 0s - loss: 0.0277 - val_loss: 0.0024
# Epoch 43/50
#  - 0s - loss: 0.0265 - val_loss: 0.0030
# Epoch 44/50
#  - 0s - loss: 0.0253 - val_loss: 0.0025
# Epoch 45/50
#  - 0s - loss: 0.0240 - val_loss: 0.0024
# Epoch 46/50
#  - 0s - loss: 0.0227 - val_loss: 0.0033
# Epoch 47/50
#  - 0s - loss: 0.0213 - val_loss: 0.0036
# Epoch 48/50
#  - 0s - loss: 0.0199 - val_loss: 0.0049
# Epoch 49/50
#  - 0s - loss: 0.0187 - val_loss: 0.0036
# Epoch 50/50
#  - 0s - loss: 0.0173 - val_loss: 0.0065
# Train RMSE: 137.0659
# Test RMSE: 19.5445
# Test MAPE: 572.1959
# [[3.8925651e-04 5.3103614e-01 5.2287583e-03 ... 6.8202770e-01
#   7.8022289e-01 2.6999998e-01]
#  [0.0000000e+00 1.8172097e-01 0.0000000e+00 ... 6.1751151e-01
#   6.6476560e-01 1.7999999e-01]
#  [0.0000000e+00 4.2572784e-01 0.0000000e+00 ... 4.7004607e-01
#   3.3966637e-01 0.0000000e+00]
#  ...
#  [3.8925651e-04 7.8467488e-01 9.2810459e-02 ... 3.8709679e-01
#   4.3990147e-01 0.0000000e+00]
#  [3.2347217e-01 6.0338187e-01 0.0000000e+00 ... 3.6866364e-01
#   4.0814674e-01 0.0000000e+00]
#  [0.0000000e+00 6.6759419e-01 6.0130719e-02 ... 5.8986175e-01
#   5.9728706e-01 2.6999998e-01]]
# [[3.89256515e-04 9.27654266e-01 7.33333349e-01 7.33333409e-01
#   4.62962966e-03 6.18055463e-01 8.01843286e-01 7.45809197e-01
#   9.99999940e-02 3.89256515e-04 6.53681517e-01 1.17647061e-02
#   1.17647061e-02 8.61111104e-01 7.36111045e-01 8.94009233e-01
#   8.85197997e-01 2.89999992e-01]
#  [3.69793698e-02 8.00299883e-01 5.75163402e-02 5.75163402e-02
#   2.31481478e-01 3.33333254e-01 4.42396373e-01 3.81594777e-01
#   0.00000000e+00 1.24562085e-02 7.08690166e-01 3.66013087e-02
#   3.66013087e-02 9.72222239e-02 3.12500000e-01 3.68663639e-01
#   2.32841492e-01 0.00000000e+00]
#  [0.00000000e+00 6.41695261e-01 9.28104594e-02 9.28104669e-02
#   7.91666687e-01 7.56944537e-01 8.43317986e-01 8.97876620e-01
#   2.19999999e-01 7.78513029e-04 6.79580450e-01 6.66666701e-02
#   6.66666701e-02 4.44444448e-01 7.29166627e-01 8.94009233e-01
#   8.65466952e-01 1.89999998e-01]
#  [2.72479560e-03 6.50256872e-01 0.00000000e+00 0.00000000e+00
#   1.00000000e+00 7.22222209e-01 9.35483932e-01 9.39882278e-01
#   0.00000000e+00 1.94628257e-03 5.77054977e-01 0.00000000e+00
#   0.00000000e+00 9.95370388e-01 7.70833135e-01 9.81566787e-01
#   9.77802634e-01 0.00000000e+00]]
# (256, 9) 256 (256,)
# (256, 1, 9) (256,) (4, 1, 9) (4,)
# Train on 256 samples, validate on 4 samples
# Epoch 1/50
#  - 1s - loss: 0.1194 - val_loss: 0.0502
# Epoch 2/50
#  - 0s - loss: 0.0755 - val_loss: 0.0133
# Epoch 3/50
#  - 0s - loss: 0.0687 - val_loss: 0.0276
# Epoch 4/50
#  - 0s - loss: 0.0735 - val_loss: 0.0236
# Epoch 5/50
#  - 0s - loss: 0.0672 - val_loss: 0.0103
# Epoch 6/50
#  - 0s - loss: 0.0607 - val_loss: 0.0142
# Epoch 7/50
#  - 0s - loss: 0.0622 - val_loss: 0.0106
# Epoch 8/50
#  - 0s - loss: 0.0582 - val_loss: 0.0106
# Epoch 9/50
#  - 0s - loss: 0.0567 - val_loss: 0.0133
# Epoch 10/50
#  - 0s - loss: 0.0549 - val_loss: 0.0082
# Epoch 11/50
#  - 0s - loss: 0.0532 - val_loss: 0.0085
# Epoch 12/50
#  - 0s - loss: 0.0514 - val_loss: 0.0113
# Epoch 13/50
#  - 0s - loss: 0.0504 - val_loss: 0.0099
# Epoch 14/50
#  - 0s - loss: 0.0491 - val_loss: 0.0089
# Epoch 15/50
#  - 0s - loss: 0.0479 - val_loss: 0.0101
# Epoch 16/50
#  - 0s - loss: 0.0471 - val_loss: 0.0085
# Epoch 17/50
#  - 0s - loss: 0.0461 - val_loss: 0.0085
# Epoch 18/50
#  - 0s - loss: 0.0453 - val_loss: 0.0074
# Epoch 19/50
#  - 0s - loss: 0.0445 - val_loss: 0.0063
# Epoch 20/50
#  - 0s - loss: 0.0438 - val_loss: 0.0051
# Epoch 21/50
#  - 0s - loss: 0.0431 - val_loss: 0.0040
# Epoch 22/50
#  - 0s - loss: 0.0425 - val_loss: 0.0036
# Epoch 23/50
#  - 0s - loss: 0.0418 - val_loss: 0.0039
# Epoch 24/50
#  - 0s - loss: 0.0413 - val_loss: 0.0037
# Epoch 25/50
#  - 0s - loss: 0.0406 - val_loss: 0.0040
# Epoch 26/50
#  - 0s - loss: 0.0400 - val_loss: 0.0032
# Epoch 27/50
#  - 0s - loss: 0.0393 - val_loss: 0.0034
# Epoch 28/50
#  - 0s - loss: 0.0387 - val_loss: 0.0027
# Epoch 29/50
#  - 0s - loss: 0.0380 - val_loss: 0.0026
# Epoch 30/50
#  - 0s - loss: 0.0373 - val_loss: 0.0025
# Epoch 31/50
#  - 0s - loss: 0.0366 - val_loss: 0.0025
# Epoch 32/50
#  - 0s - loss: 0.0359 - val_loss: 0.0031
# Epoch 33/50
#  - 0s - loss: 0.0352 - val_loss: 0.0024
# Epoch 34/50
#  - 0s - loss: 0.0344 - val_loss: 0.0028
# Epoch 35/50
#  - 0s - loss: 0.0336 - val_loss: 0.0037
# Epoch 36/50
#  - 0s - loss: 0.0329 - val_loss: 0.0029
# Epoch 37/50
#  - 0s - loss: 0.0320 - val_loss: 0.0028
# Epoch 38/50
#  - 0s - loss: 0.0311 - val_loss: 0.0033
# Epoch 39/50
#  - 0s - loss: 0.0302 - val_loss: 0.0042
# Epoch 40/50
#  - 0s - loss: 0.0295 - val_loss: 0.0039
# Epoch 41/50
#  - 0s - loss: 0.0286 - val_loss: 0.0030
# Epoch 42/50
#  - 0s - loss: 0.0276 - val_loss: 0.0035
# Epoch 43/50
#  - 0s - loss: 0.0266 - val_loss: 0.0046
# Epoch 44/50
#  - 0s - loss: 0.0256 - val_loss: 0.0055
# Epoch 45/50
#  - 0s - loss: 0.0248 - val_loss: 0.0056
# Epoch 46/50
#  - 0s - loss: 0.0238 - val_loss: 0.0046
# Epoch 47/50
#  - 0s - loss: 0.0228 - val_loss: 0.0038
# Epoch 48/50
#  - 0s - loss: 0.0216 - val_loss: 0.0054
# Epoch 49/50
#  - 0s - loss: 0.0204 - val_loss: 0.0057
# Epoch 50/50
#  - 0s - loss: 0.0194 - val_loss: 0.0073
# Train RMSE: 148.5536
# Test RMSE: 21.0221
# Test MAPE: 633.0661
# [[3.8925651e-04 5.3103614e-01 5.2287583e-03 ... 6.8202770e-01
#   7.8022289e-01 2.6999998e-01]
#  [0.0000000e+00 1.8172097e-01 0.0000000e+00 ... 6.1751151e-01
#   6.6476560e-01 1.7999999e-01]
#  [0.0000000e+00 4.2572784e-01 0.0000000e+00 ... 4.7004607e-01
#   3.3966637e-01 0.0000000e+00]
#  ...
#  [3.8925651e-04 7.8467488e-01 9.2810459e-02 ... 3.8709679e-01
#   4.3990147e-01 0.0000000e+00]
#  [3.2347217e-01 6.0338187e-01 0.0000000e+00 ... 3.6866364e-01
#   4.0814674e-01 0.0000000e+00]
#  [0.0000000e+00 6.6759419e-01 6.0130719e-02 ... 5.8986175e-01
#   5.9728706e-01 2.6999998e-01]]
# [[3.89256515e-04 9.27654266e-01 7.33333349e-01 7.33333409e-01
#   4.62962966e-03 6.18055463e-01 8.01843286e-01 7.45809197e-01
#   9.99999940e-02 3.89256515e-04 6.53681517e-01 1.17647061e-02
#   1.17647061e-02 8.61111104e-01 7.36111045e-01 8.94009233e-01
#   8.85197997e-01 2.89999992e-01]
#  [3.69793698e-02 8.00299883e-01 5.75163402e-02 5.75163402e-02
#   2.31481478e-01 3.33333254e-01 4.42396373e-01 3.81594777e-01
#   0.00000000e+00 1.24562085e-02 7.08690166e-01 3.66013087e-02
#   3.66013087e-02 9.72222239e-02 3.12500000e-01 3.68663639e-01
#   2.32841492e-01 0.00000000e+00]
#  [0.00000000e+00 6.41695261e-01 9.28104594e-02 9.28104669e-02
#   7.91666687e-01 7.56944537e-01 8.43317986e-01 8.97876620e-01
#   2.19999999e-01 7.78513029e-04 6.79580450e-01 6.66666701e-02
#   6.66666701e-02 4.44444448e-01 7.29166627e-01 8.94009233e-01
#   8.65466952e-01 1.89999998e-01]
#  [2.72479560e-03 6.50256872e-01 0.00000000e+00 0.00000000e+00
#   1.00000000e+00 7.22222209e-01 9.35483932e-01 9.39882278e-01
#   0.00000000e+00 1.94628257e-03 5.77054977e-01 0.00000000e+00
#   0.00000000e+00 9.95370388e-01 7.70833135e-01 9.81566787e-01
#   9.77802634e-01 0.00000000e+00]]
# (256, 9) 256 (256,)
# (256, 1, 9) (256,) (4, 1, 9) (4,)
# Train on 256 samples, validate on 4 samples
# Epoch 1/50
#  - 1s - loss: 0.0674 - val_loss: 0.0232
# Epoch 2/50
#  - 0s - loss: 0.0642 - val_loss: 0.0183
# Epoch 3/50
#  - 0s - loss: 0.0595 - val_loss: 0.0129
# Epoch 4/50
#  - 0s - loss: 0.0584 - val_loss: 0.0109
# Epoch 5/50
#  - 0s - loss: 0.0559 - val_loss: 0.0128
# Epoch 6/50
#  - 0s - loss: 0.0544 - val_loss: 0.0096
# Epoch 7/50
#  - 0s - loss: 0.0534 - val_loss: 0.0110
# Epoch 8/50
#  - 0s - loss: 0.0525 - val_loss: 0.0081
# Epoch 9/50
#  - 0s - loss: 0.0518 - val_loss: 0.0074
# Epoch 10/50
#  - 0s - loss: 0.0510 - val_loss: 0.0068
# Epoch 11/50
#  - 0s - loss: 0.0505 - val_loss: 0.0061
# Epoch 12/50
#  - 0s - loss: 0.0496 - val_loss: 0.0062
# Epoch 13/50
#  - 0s - loss: 0.0490 - val_loss: 0.0069
# Epoch 14/50
#  - 0s - loss: 0.0483 - val_loss: 0.0068
# Epoch 15/50
#  - 0s - loss: 0.0477 - val_loss: 0.0077
# Epoch 16/50
#  - 0s - loss: 0.0469 - val_loss: 0.0056
# Epoch 17/50
#  - 0s - loss: 0.0463 - val_loss: 0.0064
# Epoch 18/50
#  - 0s - loss: 0.0456 - val_loss: 0.0041
# Epoch 19/50
#  - 0s - loss: 0.0446 - val_loss: 0.0044
# Epoch 20/50
#  - 0s - loss: 0.0439 - val_loss: 0.0047
# Epoch 21/50
#  - 0s - loss: 0.0431 - val_loss: 0.0039
# Epoch 22/50
#  - 0s - loss: 0.0423 - val_loss: 0.0033
# Epoch 23/50
#  - 0s - loss: 0.0413 - val_loss: 0.0032
# Epoch 24/50
#  - 0s - loss: 0.0405 - val_loss: 0.0028
# Epoch 25/50
#  - 0s - loss: 0.0398 - val_loss: 0.0027
# Epoch 26/50
#  - 0s - loss: 0.0390 - val_loss: 0.0027
# Epoch 27/50
#  - 0s - loss: 0.0382 - val_loss: 0.0033
# Epoch 28/50
#  - 0s - loss: 0.0373 - val_loss: 0.0037
# Epoch 29/50
#  - 0s - loss: 0.0363 - val_loss: 0.0041
# Epoch 30/50
#  - 0s - loss: 0.0354 - val_loss: 0.0036
# Epoch 31/50
#  - 0s - loss: 0.0342 - val_loss: 0.0024
# Epoch 32/50
#  - 0s - loss: 0.0330 - val_loss: 0.0021
# Epoch 33/50
#  - 0s - loss: 0.0321 - val_loss: 0.0027
# Epoch 34/50
#  - 0s - loss: 0.0311 - val_loss: 0.0047
# Epoch 35/50
#  - 0s - loss: 0.0300 - val_loss: 0.0050
# Epoch 36/50
#  - 0s - loss: 0.0289 - val_loss: 0.0057
# Epoch 37/50
#  - 0s - loss: 0.0279 - val_loss: 0.0036
# Epoch 38/50
#  - 0s - loss: 0.0261 - val_loss: 0.0031
# Epoch 39/50
#  - 0s - loss: 0.0251 - val_loss: 0.0052
# Epoch 40/50
#  - 0s - loss: 0.0241 - val_loss: 0.0086
# Epoch 41/50
#  - 0s - loss: 0.0231 - val_loss: 0.0039
# Epoch 42/50
#  - 0s - loss: 0.0212 - val_loss: 0.0048
# Epoch 43/50
#  - 0s - loss: 0.0200 - val_loss: 0.0092
# Epoch 44/50
#  - 0s - loss: 0.0188 - val_loss: 0.0072
# Epoch 45/50
#  - 0s - loss: 0.0177 - val_loss: 0.0047
# Epoch 46/50
#  - 0s - loss: 0.0167 - val_loss: 0.0051
# Epoch 47/50
#  - 0s - loss: 0.0160 - val_loss: 0.0061
# Epoch 48/50
#  - 0s - loss: 0.0155 - val_loss: 0.0048
# Epoch 49/50
#  - 0s - loss: 0.0149 - val_loss: 0.0047
# Epoch 50/50
#  - 0s - loss: 0.0145 - val_loss: 0.0060
# Train RMSE: 109.6915
# Test RMSE: 21.0663
# Test MAPE: 514.7637
# [[3.8925651e-04 5.3103614e-01 5.2287583e-03 ... 6.8202770e-01
#   7.8022289e-01 2.6999998e-01]
#  [0.0000000e+00 1.8172097e-01 0.0000000e+00 ... 6.1751151e-01
#   6.6476560e-01 1.7999999e-01]
#  [0.0000000e+00 4.2572784e-01 0.0000000e+00 ... 4.7004607e-01
#   3.3966637e-01 0.0000000e+00]
#  ...
#  [3.8925651e-04 7.8467488e-01 9.2810459e-02 ... 3.8709679e-01
#   4.3990147e-01 0.0000000e+00]
#  [3.2347217e-01 6.0338187e-01 0.0000000e+00 ... 3.6866364e-01
#   4.0814674e-01 0.0000000e+00]
#  [0.0000000e+00 6.6759419e-01 6.0130719e-02 ... 5.8986175e-01
#   5.9728706e-01 2.6999998e-01]]
# [[3.89256515e-04 9.27654266e-01 7.33333349e-01 7.33333409e-01
#   4.62962966e-03 6.18055463e-01 8.01843286e-01 7.45809197e-01
#   9.99999940e-02 3.89256515e-04 6.53681517e-01 1.17647061e-02
#   1.17647061e-02 8.61111104e-01 7.36111045e-01 8.94009233e-01
#   8.85197997e-01 2.89999992e-01]
#  [3.69793698e-02 8.00299883e-01 5.75163402e-02 5.75163402e-02
#   2.31481478e-01 3.33333254e-01 4.42396373e-01 3.81594777e-01
#   0.00000000e+00 1.24562085e-02 7.08690166e-01 3.66013087e-02
#   3.66013087e-02 9.72222239e-02 3.12500000e-01 3.68663639e-01
#   2.32841492e-01 0.00000000e+00]
#  [0.00000000e+00 6.41695261e-01 9.28104594e-02 9.28104669e-02
#   7.91666687e-01 7.56944537e-01 8.43317986e-01 8.97876620e-01
#   2.19999999e-01 7.78513029e-04 6.79580450e-01 6.66666701e-02
#   6.66666701e-02 4.44444448e-01 7.29166627e-01 8.94009233e-01
#   8.65466952e-01 1.89999998e-01]
#  [2.72479560e-03 6.50256872e-01 0.00000000e+00 0.00000000e+00
#   1.00000000e+00 7.22222209e-01 9.35483932e-01 9.39882278e-01
#   0.00000000e+00 1.94628257e-03 5.77054977e-01 0.00000000e+00
#   0.00000000e+00 9.95370388e-01 7.70833135e-01 9.81566787e-01
#   9.77802634e-01 0.00000000e+00]]
# (256, 9) 256 (256,)
# (256, 1, 9) (256,) (4, 1, 9) (4,)
# Train on 256 samples, validate on 4 samples
# Epoch 1/50
#  - 1s - loss: 0.0586 - val_loss: 0.0110
# Epoch 2/50
#  - 0s - loss: 0.0573 - val_loss: 0.0097
# Epoch 3/50
#  - 0s - loss: 0.0550 - val_loss: 0.0082
# Epoch 4/50
#  - 0s - loss: 0.0529 - val_loss: 0.0055
# Epoch 5/50
#  - 0s - loss: 0.0520 - val_loss: 0.0039
# Epoch 6/50
#  - 0s - loss: 0.0504 - val_loss: 0.0049
# Epoch 7/50
#  - 0s - loss: 0.0497 - val_loss: 0.0028
# Epoch 8/50
#  - 0s - loss: 0.0488 - val_loss: 0.0052
# Epoch 9/50
#  - 0s - loss: 0.0480 - val_loss: 0.0038
# Epoch 10/50
#  - 0s - loss: 0.0473 - val_loss: 0.0034
# Epoch 11/50
#  - 0s - loss: 0.0465 - val_loss: 0.0028
# Epoch 12/50
#  - 0s - loss: 0.0456 - val_loss: 0.0023
# Epoch 13/50
#  - 0s - loss: 0.0448 - val_loss: 0.0030
# Epoch 14/50
#  - 0s - loss: 0.0441 - val_loss: 0.0029
# Epoch 15/50
#  - 0s - loss: 0.0436 - val_loss: 0.0031
# Epoch 16/50
#  - 0s - loss: 0.0430 - val_loss: 0.0014
# Epoch 17/50
#  - 0s - loss: 0.0420 - val_loss: 0.0024
# Epoch 18/50
#  - 0s - loss: 0.0415 - val_loss: 0.0041
# Epoch 19/50
#  - 0s - loss: 0.0408 - val_loss: 0.0041
# Epoch 20/50
#  - 0s - loss: 0.0401 - val_loss: 0.0022
# Epoch 21/50
#  - 0s - loss: 0.0390 - val_loss: 0.0027
# Epoch 22/50
#  - 0s - loss: 0.0383 - val_loss: 0.0034
# Epoch 23/50
#  - 0s - loss: 0.0375 - val_loss: 0.0031
# Epoch 24/50
#  - 0s - loss: 0.0366 - val_loss: 0.0033
# Epoch 25/50
#  - 0s - loss: 0.0358 - val_loss: 0.0034
# Epoch 26/50
#  - 0s - loss: 0.0350 - val_loss: 0.0027
# Epoch 27/50
#  - 0s - loss: 0.0339 - val_loss: 0.0026
# Epoch 28/50
#  - 0s - loss: 0.0329 - val_loss: 0.0028
# Epoch 29/50
#  - 0s - loss: 0.0319 - val_loss: 0.0027
# Epoch 30/50
#  - 0s - loss: 0.0310 - val_loss: 0.0023
# Epoch 31/50
#  - 0s - loss: 0.0300 - val_loss: 0.0027
# Epoch 32/50
#  - 0s - loss: 0.0289 - val_loss: 0.0038
# Epoch 33/50
#  - 0s - loss: 0.0278 - val_loss: 0.0047
# Epoch 34/50
#  - 0s - loss: 0.0267 - val_loss: 0.0053
# Epoch 35/50
#  - 0s - loss: 0.0256 - val_loss: 0.0065
# Epoch 36/50
#  - 0s - loss: 0.0246 - val_loss: 0.0063
# Epoch 37/50
#  - 0s - loss: 0.0232 - val_loss: 0.0050
# Epoch 38/50
#  - 0s - loss: 0.0217 - val_loss: 0.0045
# Epoch 39/50
#  - 0s - loss: 0.0204 - val_loss: 0.0047
# Epoch 40/50
#  - 0s - loss: 0.0191 - val_loss: 0.0055
# Epoch 41/50
#  - 0s - loss: 0.0182 - val_loss: 0.0051
# Epoch 42/50
#  - 0s - loss: 0.0173 - val_loss: 0.0056
# Epoch 43/50
#  - 0s - loss: 0.0167 - val_loss: 0.0074
# Epoch 44/50
#  - 0s - loss: 0.0161 - val_loss: 0.0068
# Epoch 45/50
#  - 0s - loss: 0.0153 - val_loss: 0.0063
# Epoch 46/50
#  - 0s - loss: 0.0149 - val_loss: 0.0052
# Epoch 47/50
#  - 0s - loss: 0.0145 - val_loss: 0.0057
# Epoch 48/50
#  - 0s - loss: 0.0142 - val_loss: 0.0066
# Epoch 49/50
#  - 0s - loss: 0.0140 - val_loss: 0.0062
# Epoch 50/50
#  - 0s - loss: 0.0139 - val_loss: 0.0057
# Train RMSE: 102.9203
# Test RMSE: 22.8964
# Test MAPE: 317.1614
# [[3.8925651e-04 5.3103614e-01 5.2287583e-03 ... 6.8202770e-01
#   7.8022289e-01 2.6999998e-01]
#  [0.0000000e+00 1.8172097e-01 0.0000000e+00 ... 6.1751151e-01
#   6.6476560e-01 1.7999999e-01]
#  [0.0000000e+00 4.2572784e-01 0.0000000e+00 ... 4.7004607e-01
#   3.3966637e-01 0.0000000e+00]
#  ...
#  [3.8925651e-04 7.8467488e-01 9.2810459e-02 ... 3.8709679e-01
#   4.3990147e-01 0.0000000e+00]
#  [3.2347217e-01 6.0338187e-01 0.0000000e+00 ... 3.6866364e-01
#   4.0814674e-01 0.0000000e+00]
#  [0.0000000e+00 6.6759419e-01 6.0130719e-02 ... 5.8986175e-01
#   5.9728706e-01 2.6999998e-01]]
# [[3.89256515e-04 9.27654266e-01 7.33333349e-01 7.33333409e-01
#   4.62962966e-03 6.18055463e-01 8.01843286e-01 7.45809197e-01
#   9.99999940e-02 3.89256515e-04 6.53681517e-01 1.17647061e-02
#   1.17647061e-02 8.61111104e-01 7.36111045e-01 8.94009233e-01
#   8.85197997e-01 2.89999992e-01]
#  [3.69793698e-02 8.00299883e-01 5.75163402e-02 5.75163402e-02
#   2.31481478e-01 3.33333254e-01 4.42396373e-01 3.81594777e-01
#   0.00000000e+00 1.24562085e-02 7.08690166e-01 3.66013087e-02
#   3.66013087e-02 9.72222239e-02 3.12500000e-01 3.68663639e-01
#   2.32841492e-01 0.00000000e+00]
#  [0.00000000e+00 6.41695261e-01 9.28104594e-02 9.28104669e-02
#   7.91666687e-01 7.56944537e-01 8.43317986e-01 8.97876620e-01
#   2.19999999e-01 7.78513029e-04 6.79580450e-01 6.66666701e-02
#   6.66666701e-02 4.44444448e-01 7.29166627e-01 8.94009233e-01
#   8.65466952e-01 1.89999998e-01]
#  [2.72479560e-03 6.50256872e-01 0.00000000e+00 0.00000000e+00
#   1.00000000e+00 7.22222209e-01 9.35483932e-01 9.39882278e-01
#   0.00000000e+00 1.94628257e-03 5.77054977e-01 0.00000000e+00
#   0.00000000e+00 9.95370388e-01 7.70833135e-01 9.81566787e-01
#   9.77802634e-01 0.00000000e+00]]
# (256, 9) 256 (256,)
# (256, 1, 9) (256,) (4, 1, 9) (4,)
# Train on 256 samples, validate on 4 samples
# Epoch 1/50
#  - 1s - loss: 0.0646 - val_loss: 0.0175
# Epoch 2/50
#  - 0s - loss: 0.0603 - val_loss: 0.0089
# Epoch 3/50
#  - 0s - loss: 0.0571 - val_loss: 0.0069
# Epoch 4/50
#  - 0s - loss: 0.0551 - val_loss: 0.0092
# Epoch 5/50
#  - 0s - loss: 0.0538 - val_loss: 0.0086
# Epoch 6/50
#  - 0s - loss: 0.0527 - val_loss: 0.0103
# Epoch 7/50
#  - 0s - loss: 0.0522 - val_loss: 0.0074
# Epoch 8/50
#  - 0s - loss: 0.0510 - val_loss: 0.0067
# Epoch 9/50
#  - 0s - loss: 0.0503 - val_loss: 0.0038
# Epoch 10/50
#  - 0s - loss: 0.0493 - val_loss: 0.0028
# Epoch 11/50
#  - 0s - loss: 0.0487 - val_loss: 0.0022
# Epoch 12/50
#  - 0s - loss: 0.0479 - val_loss: 0.0020
# Epoch 13/50
#  - 0s - loss: 0.0471 - val_loss: 0.0038
# Epoch 14/50
#  - 0s - loss: 0.0466 - val_loss: 0.0031
# Epoch 15/50
#  - 0s - loss: 0.0458 - val_loss: 0.0022
# Epoch 16/50
#  - 0s - loss: 0.0449 - val_loss: 0.0024
# Epoch 17/50
#  - 0s - loss: 0.0444 - val_loss: 0.0027
# Epoch 18/50
#  - 0s - loss: 0.0438 - val_loss: 0.0021
# Epoch 19/50
#  - 0s - loss: 0.0428 - val_loss: 0.0027
# Epoch 20/50
#  - 0s - loss: 0.0421 - val_loss: 0.0027
# Epoch 21/50
#  - 0s - loss: 0.0414 - val_loss: 0.0027
# Epoch 22/50
#  - 0s - loss: 0.0407 - val_loss: 0.0031
# Epoch 23/50
#  - 0s - loss: 0.0401 - val_loss: 0.0031
# Epoch 24/50
#  - 0s - loss: 0.0393 - val_loss: 0.0023
# Epoch 25/50
#  - 0s - loss: 0.0383 - val_loss: 0.0022
# Epoch 26/50
#  - 0s - loss: 0.0376 - val_loss: 0.0024
# Epoch 27/50
#  - 0s - loss: 0.0368 - val_loss: 0.0026
# Epoch 28/50
#  - 0s - loss: 0.0360 - val_loss: 0.0033
# Epoch 29/50
#  - 0s - loss: 0.0351 - val_loss: 0.0026
# Epoch 30/50
#  - 0s - loss: 0.0342 - val_loss: 0.0017
# Epoch 31/50
#  - 0s - loss: 0.0333 - val_loss: 0.0026
# Epoch 32/50
#  - 0s - loss: 0.0328 - val_loss: 0.0050
# Epoch 33/50
#  - 0s - loss: 0.0318 - val_loss: 0.0046
# Epoch 34/50
#  - 0s - loss: 0.0307 - val_loss: 0.0042
# Epoch 35/50
#  - 0s - loss: 0.0295 - val_loss: 0.0038
# Epoch 36/50
#  - 0s - loss: 0.0284 - val_loss: 0.0032
# Epoch 37/50
#  - 0s - loss: 0.0274 - val_loss: 0.0027
# Epoch 38/50
#  - 0s - loss: 0.0265 - val_loss: 0.0034
# Epoch 39/50
#  - 0s - loss: 0.0256 - val_loss: 0.0055
# Epoch 40/50
#  - 0s - loss: 0.0246 - val_loss: 0.0063
# Epoch 41/50
#  - 0s - loss: 0.0234 - val_loss: 0.0062
# Epoch 42/50
#  - 0s - loss: 0.0221 - val_loss: 0.0052
# Epoch 43/50
#  - 0s - loss: 0.0207 - val_loss: 0.0039
# Epoch 44/50
#  - 0s - loss: 0.0197 - val_loss: 0.0037
# Epoch 45/50
#  - 0s - loss: 0.0193 - val_loss: 0.0064
# Epoch 46/50
#  - 0s - loss: 0.0187 - val_loss: 0.0088
# Epoch 47/50
#  - 0s - loss: 0.0178 - val_loss: 0.0062
# Epoch 48/50
#  - 0s - loss: 0.0168 - val_loss: 0.0056
# Epoch 49/50
#  - 0s - loss: 0.0161 - val_loss: 0.0066
# Epoch 50/50
#  - 0s - loss: 0.0160 - val_loss: 0.0085
# Train RMSE: 117.4817
# Test RMSE: 26.3922
# Test MAPE: 958.0902
# [[3.8925651e-04 5.3103614e-01 5.2287583e-03 ... 6.8202770e-01
#   7.8022289e-01 2.6999998e-01]
#  [0.0000000e+00 1.8172097e-01 0.0000000e+00 ... 6.1751151e-01
#   6.6476560e-01 1.7999999e-01]
#  [0.0000000e+00 4.2572784e-01 0.0000000e+00 ... 4.7004607e-01
#   3.3966637e-01 0.0000000e+00]
#  ...
#  [3.8925651e-04 7.8467488e-01 9.2810459e-02 ... 3.8709679e-01
#   4.3990147e-01 0.0000000e+00]
#  [3.2347217e-01 6.0338187e-01 0.0000000e+00 ... 3.6866364e-01
#   4.0814674e-01 0.0000000e+00]
#  [0.0000000e+00 6.6759419e-01 6.0130719e-02 ... 5.8986175e-01
#   5.9728706e-01 2.6999998e-01]]
# [[3.89256515e-04 9.27654266e-01 7.33333349e-01 7.33333409e-01
#   4.62962966e-03 6.18055463e-01 8.01843286e-01 7.45809197e-01
#   9.99999940e-02 3.89256515e-04 6.53681517e-01 1.17647061e-02
#   1.17647061e-02 8.61111104e-01 7.36111045e-01 8.94009233e-01
#   8.85197997e-01 2.89999992e-01]
#  [3.69793698e-02 8.00299883e-01 5.75163402e-02 5.75163402e-02
#   2.31481478e-01 3.33333254e-01 4.42396373e-01 3.81594777e-01
#   0.00000000e+00 1.24562085e-02 7.08690166e-01 3.66013087e-02
#   3.66013087e-02 9.72222239e-02 3.12500000e-01 3.68663639e-01
#   2.32841492e-01 0.00000000e+00]
#  [0.00000000e+00 6.41695261e-01 9.28104594e-02 9.28104669e-02
#   7.91666687e-01 7.56944537e-01 8.43317986e-01 8.97876620e-01
#   2.19999999e-01 7.78513029e-04 6.79580450e-01 6.66666701e-02
#   6.66666701e-02 4.44444448e-01 7.29166627e-01 8.94009233e-01
#   8.65466952e-01 1.89999998e-01]
#  [2.72479560e-03 6.50256872e-01 0.00000000e+00 0.00000000e+00
#   1.00000000e+00 7.22222209e-01 9.35483932e-01 9.39882278e-01
#   0.00000000e+00 1.94628257e-03 5.77054977e-01 0.00000000e+00
#   0.00000000e+00 9.95370388e-01 7.70833135e-01 9.81566787e-01
#   9.77802634e-01 0.00000000e+00]]
# (256, 9) 256 (256,)
# (256, 1, 9) (256,) (4, 1, 9) (4,)
# Train on 256 samples, validate on 4 samples
# Epoch 1/50
#  - 1s - loss: 0.0809 - val_loss: 0.0223
# Epoch 2/50
#  - 0s - loss: 0.0653 - val_loss: 0.0366
# Epoch 3/50
#  - 0s - loss: 0.0684 - val_loss: 0.0315
# Epoch 4/50
#  - 0s - loss: 0.0623 - val_loss: 0.0179
# Epoch 5/50
#  - 0s - loss: 0.0602 - val_loss: 0.0128
# Epoch 6/50
#  - 0s - loss: 0.0592 - val_loss: 0.0200
# Epoch 7/50
#  - 0s - loss: 0.0568 - val_loss: 0.0245
# Epoch 8/50
#  - 0s - loss: 0.0563 - val_loss: 0.0205
# Epoch 9/50
#  - 0s - loss: 0.0550 - val_loss: 0.0158
# Epoch 10/50
#  - 0s - loss: 0.0545 - val_loss: 0.0162
# Epoch 11/50
#  - 0s - loss: 0.0532 - val_loss: 0.0180
# Epoch 12/50
#  - 0s - loss: 0.0528 - val_loss: 0.0146
# Epoch 13/50
#  - 0s - loss: 0.0520 - val_loss: 0.0107
# Epoch 14/50
#  - 0s - loss: 0.0511 - val_loss: 0.0109
# Epoch 15/50
#  - 0s - loss: 0.0504 - val_loss: 0.0090
# Epoch 16/50
#  - 0s - loss: 0.0498 - val_loss: 0.0075
# Epoch 17/50
#  - 0s - loss: 0.0490 - val_loss: 0.0075
# Epoch 18/50
#  - 0s - loss: 0.0484 - val_loss: 0.0064
# Epoch 19/50
#  - 0s - loss: 0.0477 - val_loss: 0.0062
# Epoch 20/50
#  - 0s - loss: 0.0470 - val_loss: 0.0063
# Epoch 21/50
#  - 0s - loss: 0.0463 - val_loss: 0.0057
# Epoch 22/50
#  - 0s - loss: 0.0456 - val_loss: 0.0057
# Epoch 23/50
#  - 0s - loss: 0.0448 - val_loss: 0.0053
# Epoch 24/50
#  - 0s - loss: 0.0441 - val_loss: 0.0051
# Epoch 25/50
#  - 0s - loss: 0.0433 - val_loss: 0.0043
# Epoch 26/50
#  - 0s - loss: 0.0426 - val_loss: 0.0043
# Epoch 27/50
#  - 0s - loss: 0.0418 - val_loss: 0.0037
# Epoch 28/50
#  - 0s - loss: 0.0410 - val_loss: 0.0031
# Epoch 29/50
#  - 0s - loss: 0.0401 - val_loss: 0.0033
# Epoch 30/50
#  - 0s - loss: 0.0394 - val_loss: 0.0027
# Epoch 31/50
#  - 0s - loss: 0.0384 - val_loss: 0.0023
# Epoch 32/50
#  - 0s - loss: 0.0375 - val_loss: 0.0027
# Epoch 33/50
#  - 0s - loss: 0.0366 - val_loss: 0.0026
# Epoch 34/50
#  - 0s - loss: 0.0357 - val_loss: 0.0028
# Epoch 35/50
#  - 0s - loss: 0.0347 - val_loss: 0.0037
# Epoch 36/50
#  - 0s - loss: 0.0338 - val_loss: 0.0038
# Epoch 37/50
#  - 0s - loss: 0.0328 - val_loss: 0.0037
# Epoch 38/50
#  - 0s - loss: 0.0317 - val_loss: 0.0036
# Epoch 39/50
#  - 0s - loss: 0.0305 - val_loss: 0.0031
# Epoch 40/50
#  - 0s - loss: 0.0294 - val_loss: 0.0040
# Epoch 41/50
#  - 0s - loss: 0.0283 - val_loss: 0.0052
# Epoch 42/50
#  - 0s - loss: 0.0274 - val_loss: 0.0069
# Epoch 43/50
#  - 0s - loss: 0.0265 - val_loss: 0.0042
# Epoch 44/50
#  - 0s - loss: 0.0245 - val_loss: 0.0054
# Epoch 45/50
#  - 0s - loss: 0.0234 - val_loss: 0.0073
# Epoch 46/50
#  - 0s - loss: 0.0223 - val_loss: 0.0068
# Epoch 47/50
#  - 0s - loss: 0.0209 - val_loss: 0.0053
# Epoch 48/50
#  - 0s - loss: 0.0193 - val_loss: 0.0050
# Epoch 49/50
#  - 0s - loss: 0.0184 - val_loss: 0.0054
# Epoch 50/50
#  - 0s - loss: 0.0177 - val_loss: 0.0064
# Train RMSE: 128.5090
# Test RMSE: 21.8194
# Test MAPE: 280.1527
# [[3.8925651e-04 5.3103614e-01 5.2287583e-03 ... 6.8202770e-01
#   7.8022289e-01 2.6999998e-01]
#  [0.0000000e+00 1.8172097e-01 0.0000000e+00 ... 6.1751151e-01
#   6.6476560e-01 1.7999999e-01]
#  [0.0000000e+00 4.2572784e-01 0.0000000e+00 ... 4.7004607e-01
#   3.3966637e-01 0.0000000e+00]
#  ...
#  [3.8925651e-04 7.8467488e-01 9.2810459e-02 ... 3.8709679e-01
#   4.3990147e-01 0.0000000e+00]
#  [3.2347217e-01 6.0338187e-01 0.0000000e+00 ... 3.6866364e-01
#   4.0814674e-01 0.0000000e+00]
#  [0.0000000e+00 6.6759419e-01 6.0130719e-02 ... 5.8986175e-01
#   5.9728706e-01 2.6999998e-01]]
# [[3.89256515e-04 9.27654266e-01 7.33333349e-01 7.33333409e-01
#   4.62962966e-03 6.18055463e-01 8.01843286e-01 7.45809197e-01
#   9.99999940e-02 3.89256515e-04 6.53681517e-01 1.17647061e-02
#   1.17647061e-02 8.61111104e-01 7.36111045e-01 8.94009233e-01
#   8.85197997e-01 2.89999992e-01]
#  [3.69793698e-02 8.00299883e-01 5.75163402e-02 5.75163402e-02
#   2.31481478e-01 3.33333254e-01 4.42396373e-01 3.81594777e-01
#   0.00000000e+00 1.24562085e-02 7.08690166e-01 3.66013087e-02
#   3.66013087e-02 9.72222239e-02 3.12500000e-01 3.68663639e-01
#   2.32841492e-01 0.00000000e+00]
#  [0.00000000e+00 6.41695261e-01 9.28104594e-02 9.28104669e-02
#   7.91666687e-01 7.56944537e-01 8.43317986e-01 8.97876620e-01
#   2.19999999e-01 7.78513029e-04 6.79580450e-01 6.66666701e-02
#   6.66666701e-02 4.44444448e-01 7.29166627e-01 8.94009233e-01
#   8.65466952e-01 1.89999998e-01]
#  [2.72479560e-03 6.50256872e-01 0.00000000e+00 0.00000000e+00
#   1.00000000e+00 7.22222209e-01 9.35483932e-01 9.39882278e-01
#   0.00000000e+00 1.94628257e-03 5.77054977e-01 0.00000000e+00
#   0.00000000e+00 9.95370388e-01 7.70833135e-01 9.81566787e-01
#   9.77802634e-01 0.00000000e+00]]
# (256, 9) 256 (256,)
# (256, 1, 9) (256,) (4, 1, 9) (4,)
# Train on 256 samples, validate on 4 samples
# Epoch 1/50
#  - 2s - loss: 0.0741 - val_loss: 0.0215
# Epoch 2/50
#  - 0s - loss: 0.0645 - val_loss: 0.0279
# Epoch 3/50
#  - 0s - loss: 0.0610 - val_loss: 0.0162
# Epoch 4/50
#  - 0s - loss: 0.0602 - val_loss: 0.0169
# Epoch 5/50
#  - 0s - loss: 0.0581 - val_loss: 0.0161
# Epoch 6/50
#  - 0s - loss: 0.0568 - val_loss: 0.0139
# Epoch 7/50
#  - 0s - loss: 0.0545 - val_loss: 0.0116
# Epoch 8/50
#  - 0s - loss: 0.0536 - val_loss: 0.0098
# Epoch 9/50
#  - 0s - loss: 0.0523 - val_loss: 0.0085
# Epoch 10/50
#  - 0s - loss: 0.0509 - val_loss: 0.0075
# Epoch 11/50
#  - 0s - loss: 0.0500 - val_loss: 0.0052
# Epoch 12/50
#  - 0s - loss: 0.0487 - val_loss: 0.0033
# Epoch 13/50
#  - 0s - loss: 0.0476 - val_loss: 0.0040
# Epoch 14/50
#  - 0s - loss: 0.0466 - val_loss: 0.0020
# Epoch 15/50
#  - 0s - loss: 0.0458 - val_loss: 0.0052
# Epoch 16/50
#  - 0s - loss: 0.0451 - val_loss: 0.0032
# Epoch 17/50
#  - 0s - loss: 0.0442 - val_loss: 0.0022
# Epoch 18/50
#  - 0s - loss: 0.0434 - val_loss: 0.0021
# Epoch 19/50
#  - 0s - loss: 0.0425 - val_loss: 0.0011
# Epoch 20/50
#  - 0s - loss: 0.0417 - val_loss: 9.2067e-04
# Epoch 21/50
#  - 0s - loss: 0.0411 - val_loss: 7.6598e-04
# Epoch 22/50
#  - 0s - loss: 0.0405 - val_loss: 0.0020
# Epoch 23/50
#  - 0s - loss: 0.0399 - val_loss: 0.0028
# Epoch 24/50
#  - 0s - loss: 0.0391 - val_loss: 0.0016
# Epoch 25/50
#  - 0s - loss: 0.0381 - val_loss: 0.0019
# Epoch 26/50
#  - 0s - loss: 0.0374 - val_loss: 0.0029
# Epoch 27/50
#  - 0s - loss: 0.0365 - val_loss: 0.0026
# Epoch 28/50
#  - 0s - loss: 0.0356 - val_loss: 0.0028
# Epoch 29/50
#  - 0s - loss: 0.0348 - val_loss: 0.0037
# Epoch 30/50
#  - 0s - loss: 0.0340 - val_loss: 0.0028
# Epoch 31/50
#  - 0s - loss: 0.0329 - val_loss: 0.0022
# Epoch 32/50
#  - 0s - loss: 0.0319 - val_loss: 0.0019
# Epoch 33/50
#  - 0s - loss: 0.0308 - val_loss: 0.0026
# Epoch 34/50
#  - 0s - loss: 0.0297 - val_loss: 0.0033
# Epoch 35/50
#  - 0s - loss: 0.0286 - val_loss: 0.0033
# Epoch 36/50
#  - 0s - loss: 0.0276 - val_loss: 0.0033
# Epoch 37/50
#  - 0s - loss: 0.0266 - val_loss: 0.0044
# Epoch 38/50
#  - 0s - loss: 0.0256 - val_loss: 0.0060
# Epoch 39/50
#  - 0s - loss: 0.0246 - val_loss: 0.0060
# Epoch 40/50
#  - 0s - loss: 0.0231 - val_loss: 0.0051
# Epoch 41/50
#  - 0s - loss: 0.0216 - val_loss: 0.0047
# Epoch 42/50
#  - 0s - loss: 0.0203 - val_loss: 0.0043
# Epoch 43/50
#  - 0s - loss: 0.0191 - val_loss: 0.0045
# Epoch 44/50
#  - 0s - loss: 0.0179 - val_loss: 0.0048
# Epoch 45/50
#  - 0s - loss: 0.0171 - val_loss: 0.0055
# Epoch 46/50
#  - 0s - loss: 0.0165 - val_loss: 0.0068
# Epoch 47/50
#  - 0s - loss: 0.0160 - val_loss: 0.0074
# Epoch 48/50
#  - 0s - loss: 0.0156 - val_loss: 0.0094
# Epoch 49/50
#  - 0s - loss: 0.0161 - val_loss: 0.0045
# Epoch 50/50
#  - 0s - loss: 0.0156 - val_loss: 0.0059
# Train RMSE: 109.5131
# Test RMSE: 20.2333
# Test MAPE: 451.5216
# [[3.8925651e-04 5.3103614e-01 5.2287583e-03 ... 6.8202770e-01
#   7.8022289e-01 2.6999998e-01]
#  [0.0000000e+00 1.8172097e-01 0.0000000e+00 ... 6.1751151e-01
#   6.6476560e-01 1.7999999e-01]
#  [0.0000000e+00 4.2572784e-01 0.0000000e+00 ... 4.7004607e-01
#   3.3966637e-01 0.0000000e+00]
#  ...
#  [3.8925651e-04 7.8467488e-01 9.2810459e-02 ... 3.8709679e-01
#   4.3990147e-01 0.0000000e+00]
#  [3.2347217e-01 6.0338187e-01 0.0000000e+00 ... 3.6866364e-01
#   4.0814674e-01 0.0000000e+00]
#  [0.0000000e+00 6.6759419e-01 6.0130719e-02 ... 5.8986175e-01
#   5.9728706e-01 2.6999998e-01]]
# [[3.89256515e-04 9.27654266e-01 7.33333349e-01 7.33333409e-01
#   4.62962966e-03 6.18055463e-01 8.01843286e-01 7.45809197e-01
#   9.99999940e-02 3.89256515e-04 6.53681517e-01 1.17647061e-02
#   1.17647061e-02 8.61111104e-01 7.36111045e-01 8.94009233e-01
#   8.85197997e-01 2.89999992e-01]
#  [3.69793698e-02 8.00299883e-01 5.75163402e-02 5.75163402e-02
#   2.31481478e-01 3.33333254e-01 4.42396373e-01 3.81594777e-01
#   0.00000000e+00 1.24562085e-02 7.08690166e-01 3.66013087e-02
#   3.66013087e-02 9.72222239e-02 3.12500000e-01 3.68663639e-01
#   2.32841492e-01 0.00000000e+00]
#  [0.00000000e+00 6.41695261e-01 9.28104594e-02 9.28104669e-02
#   7.91666687e-01 7.56944537e-01 8.43317986e-01 8.97876620e-01
#   2.19999999e-01 7.78513029e-04 6.79580450e-01 6.66666701e-02
#   6.66666701e-02 4.44444448e-01 7.29166627e-01 8.94009233e-01
#   8.65466952e-01 1.89999998e-01]
#  [2.72479560e-03 6.50256872e-01 0.00000000e+00 0.00000000e+00
#   1.00000000e+00 7.22222209e-01 9.35483932e-01 9.39882278e-01
#   0.00000000e+00 1.94628257e-03 5.77054977e-01 0.00000000e+00
#   0.00000000e+00 9.95370388e-01 7.70833135e-01 9.81566787e-01
#   9.77802634e-01 0.00000000e+00]]
# (256, 9) 256 (256,)
# (256, 1, 9) (256,) (4, 1, 9) (4,)
# Train on 256 samples, validate on 4 samples
# Epoch 1/50
#  - 2s - loss: 0.0805 - val_loss: 0.0183
# Epoch 2/50
#  - 0s - loss: 0.0613 - val_loss: 0.0180
# Epoch 3/50
#  - 0s - loss: 0.0603 - val_loss: 0.0128
# Epoch 4/50
#  - 0s - loss: 0.0587 - val_loss: 0.0164
# Epoch 5/50
#  - 0s - loss: 0.0565 - val_loss: 0.0065
# Epoch 6/50
#  - 0s - loss: 0.0545 - val_loss: 0.0070
# Epoch 7/50
#  - 0s - loss: 0.0527 - val_loss: 0.0117
# Epoch 8/50
#  - 0s - loss: 0.0525 - val_loss: 0.0067
# Epoch 9/50
#  - 0s - loss: 0.0514 - val_loss: 0.0060
# Epoch 10/50
#  - 0s - loss: 0.0504 - val_loss: 0.0073
# Epoch 11/50
#  - 0s - loss: 0.0499 - val_loss: 0.0037
# Epoch 12/50
#  - 0s - loss: 0.0490 - val_loss: 0.0052
# Epoch 13/50
#  - 0s - loss: 0.0484 - val_loss: 0.0035
# Epoch 14/50
#  - 0s - loss: 0.0475 - val_loss: 0.0043
# Epoch 15/50
#  - 0s - loss: 0.0469 - val_loss: 0.0032
# Epoch 16/50
#  - 0s - loss: 0.0461 - val_loss: 0.0039
# Epoch 17/50
#  - 0s - loss: 0.0455 - val_loss: 0.0026
# Epoch 18/50
#  - 0s - loss: 0.0447 - val_loss: 0.0026
# Epoch 19/50
#  - 0s - loss: 0.0440 - val_loss: 0.0027
# Epoch 20/50
#  - 0s - loss: 0.0433 - val_loss: 0.0021
# Epoch 21/50
#  - 0s - loss: 0.0425 - val_loss: 0.0021
# Epoch 22/50
#  - 0s - loss: 0.0417 - val_loss: 0.0028
# Epoch 23/50
#  - 0s - loss: 0.0411 - val_loss: 0.0027
# Epoch 24/50
#  - 0s - loss: 0.0403 - val_loss: 0.0023
# Epoch 25/50
#  - 0s - loss: 0.0394 - val_loss: 0.0024
# Epoch 26/50
#  - 0s - loss: 0.0386 - val_loss: 0.0033
# Epoch 27/50
#  - 0s - loss: 0.0379 - val_loss: 0.0022
# Epoch 28/50
#  - 0s - loss: 0.0369 - val_loss: 0.0023
# Epoch 29/50
#  - 0s - loss: 0.0359 - val_loss: 0.0034
# Epoch 30/50
#  - 0s - loss: 0.0352 - val_loss: 0.0036
# Epoch 31/50
#  - 0s - loss: 0.0343 - val_loss: 0.0025
# Epoch 32/50
#  - 0s - loss: 0.0331 - val_loss: 0.0028
# Epoch 33/50
#  - 0s - loss: 0.0319 - val_loss: 0.0041
# Epoch 34/50
#  - 0s - loss: 0.0310 - val_loss: 0.0053
# Epoch 35/50
#  - 0s - loss: 0.0303 - val_loss: 0.0033
# Epoch 36/50
#  - 0s - loss: 0.0287 - val_loss: 0.0041
# Epoch 37/50
#  - 0s - loss: 0.0274 - val_loss: 0.0059
# Epoch 38/50
#  - 0s - loss: 0.0264 - val_loss: 0.0061
# Epoch 39/50
#  - 0s - loss: 0.0254 - val_loss: 0.0041
# Epoch 40/50
#  - 0s - loss: 0.0239 - val_loss: 0.0041
# Epoch 41/50
#  - 0s - loss: 0.0223 - val_loss: 0.0061
# Epoch 42/50
#  - 0s - loss: 0.0211 - val_loss: 0.0069
# Epoch 43/50
#  - 0s - loss: 0.0199 - val_loss: 0.0061
# Epoch 44/50
#  - 0s - loss: 0.0187 - val_loss: 0.0058
# Epoch 45/50
#  - 0s - loss: 0.0178 - val_loss: 0.0060
# Epoch 46/50
#  - 0s - loss: 0.0172 - val_loss: 0.0061
# Epoch 47/50
#  - 0s - loss: 0.0163 - val_loss: 0.0068
# Epoch 48/50
#  - 0s - loss: 0.0157 - val_loss: 0.0075
# Epoch 49/50
#  - 0s - loss: 0.0154 - val_loss: 0.0079
# Epoch 50/50
#  - 0s - loss: 0.0150 - val_loss: 0.0079
# Train RMSE: 108.8914
# Test RMSE: 25.0079
# Test MAPE: 750.0761
